# %% [markdown]
# <a href="https://colab.research.google.com/github/Asmaaad37/Machine-Learning/blob/main/Olympics-EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
bios = pd.read_csv('bios.csv')

# %%
bios.head()
# Out:
#                                        Roles   Sex  \
# 0                  Competed in Olympic Games  Male
# 1                  Competed in Olympic Games  Male
# 2  Competed in Olympic Games • Administrator  Male
# 3                  Competed in Olympic Games  Male
# 4                  Competed in Olympic Games  Male
#
#                                            Full name              Used name  \
# 0  François Joseph Marie Antoine "Jean-François"•...  Jean-François•Blanchy
# 1                            Arnaud Benjamin•Boetsch         Arnaud•Boetsch
# 2                        Jean Laurent Robert•Borotra           Jean•Borotra
# 3               Jacques Marie Stanislas Jean•Brugnon        Jacques•Brugnon
# 4                                 Henry Albert•Canet           Albert•Canet
#
#                                                 Born  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)
# 1             1 April 1969 in Meulan, Yvelines (FRA)
# 2  13 August 1898 in Biarritz, Pyrénées-Atlantiqu...
# 3            11 May 1895 in Paris VIIIe, Paris (FRA)
# 4         17 April 1878 in Wandsworth, England (GBR)
#
#                                                 Died     NOC  athlete_id  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...  France         1.0
# 1                                                NaN  France         2.0
# 2  17 July 1994 in Arbonne, Pyrénées-Atlantiques ...  France         3.0
# 3              20 March 1978 in Monaco, Monaco (MON)  France         4.0
# 4            25 July 1930 in Paris VIIe, Paris (FRA)  France         5.0
#
#      Measurements                         Affiliations  \
# 0             NaN                                  NaN
# 1  183 cm / 76 kg   Racing Club de France, Paris (FRA)
# 2  183 cm / 76 kg                     TCP, Paris (FRA)
# 3  168 cm / 64 kg  Sporting club de Paris, Paris (FRA)
# 4             NaN                     TCP, Paris (FRA)
#
#                                 Nick/petnames Title(s) Other names  \
# 0                                         NaN      NaN         NaN
# 1                                         NaN      NaN         NaN
# 2  Le Basque Bondissant (The Bounding Basque)      NaN         NaN
# 3                                        Toto      NaN         NaN
# 4                                         NaN      NaN         NaN
#
#   Nationality Original name Name order
# 0         NaN           NaN        NaN
# 1         NaN           NaN        NaN
# 2         NaN           NaN        NaN
# 3         NaN           NaN        NaN
# 4         NaN           NaN        NaN

# %%
# What should we clean ?
# Get Rid of bullet points in Used Names [Done]
# Get Rid of Extra Columns [Done]
# Split Height/Weight [Done]
# Parse Out dates from 'Born' and 'Died' column [Done]
# Parese Out city, region and country from 'Born' column [Done]

# %%
# Making the copy of the original data
df = bios.copy()

# %%
df['name'] = df['Used name'].str.replace("•", " ")
# df.drop('Name', axis=1, inplace=True)

# %%
df.head()
# Out:
#                                        Roles   Sex  \
# 0                  Competed in Olympic Games  Male
# 1                  Competed in Olympic Games  Male
# 2  Competed in Olympic Games • Administrator  Male
# 3                  Competed in Olympic Games  Male
# 4                  Competed in Olympic Games  Male
#
#                                            Full name              Used name  \
# 0  François Joseph Marie Antoine "Jean-François"•...  Jean-François•Blanchy
# 1                            Arnaud Benjamin•Boetsch         Arnaud•Boetsch
# 2                        Jean Laurent Robert•Borotra           Jean•Borotra
# 3               Jacques Marie Stanislas Jean•Brugnon        Jacques•Brugnon
# 4                                 Henry Albert•Canet           Albert•Canet
#
#                                                 Born  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)
# 1             1 April 1969 in Meulan, Yvelines (FRA)
# 2  13 August 1898 in Biarritz, Pyrénées-Atlantiqu...
# 3            11 May 1895 in Paris VIIIe, Paris (FRA)
# 4         17 April 1878 in Wandsworth, England (GBR)
#
#                                                 Died     NOC  athlete_id  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...  France         1.0
# 1                                                NaN  France         2.0
# 2  17 July 1994 in Arbonne, Pyrénées-Atlantiques ...  France         3.0
# 3              20 March 1978 in Monaco, Monaco (MON)  France         4.0
# 4            25 July 1930 in Paris VIIe, Paris (FRA)  France         5.0
#
#      Measurements                         Affiliations  \
# 0             NaN                                  NaN
# 1  183 cm / 76 kg   Racing Club de France, Paris (FRA)
# 2  183 cm / 76 kg                     TCP, Paris (FRA)
# 3  168 cm / 64 kg  Sporting club de Paris, Paris (FRA)
# 4             NaN                     TCP, Paris (FRA)
#
#                                 Nick/petnames Title(s) Other names  \
# 0                                         NaN      NaN         NaN
# 1                                         NaN      NaN         NaN
# 2  Le Basque Bondissant (The Bounding Basque)      NaN         NaN
# 3                                        Toto      NaN         NaN
# 4                                         NaN      NaN         NaN
#
#   Nationality Original name Name order                   name
# 0         NaN           NaN        NaN  Jean-François Blanchy
# 1         NaN           NaN        NaN         Arnaud Boetsch
# 2         NaN           NaN        NaN           Jean Borotra
# 3         NaN           NaN        NaN        Jacques Brugnon
# 4         NaN           NaN        NaN           Albert Canet

# %%
# Splitting Height / Weight
# df.drop(columns=['height', 'weight'], inplace=True)
df[['height_cm', 'weight_kg']] = df['Measurements'].str.split('/', expand=True)

# %%
# Check to make sure values have the '/'.
df[~df['Measurements'].str.contains('/', na=False) & df['Measurements'].notna()]
# small_data = pd.DataFrame(['183 cm', '180 cm / 150 kg', '190 cm / 80 kg', '100 kg'], columns = ["Measurements"])
# small_data[['height_cm', 'weight_kg']] = small_data['Measurements'].str.split('/', expand=True)
# small_data['weight_kg'].fillna(small_data['height_cm'], inplace=True)

# small_data['height_cm'] = pd.to_numeric(small_data['height_cm'].str.strip(' cm'), errors='coerce')
# small_data['weight_kg'] = pd.to_numeric(small_data['weight_kg'].str.strip(' kg'), errors='coerce')

# small_data.head()

# Get Rid of 'cm' and 'kg' from our new column
# Out:
#                                          Roles     Sex  \
# 87     Competed in Olympic Games • Non-starter    Male
# 105                  Competed in Olympic Games    Male
# 165                  Competed in Olympic Games  Female
# 242                  Competed in Olympic Games  Female
# 243                  Competed in Olympic Games  Female
# ...                                        ...     ...
# 21999                Competed in Olympic Games    Male
# 22007                Competed in Olympic Games    Male
# 22046      Competed in Olympic Games • Referee    Male
# 22050      Competed in Olympic Games • Referee    Male
# 22090      Competed in Olympic Games • Referee    Male
#
#                                      Full name             Used name  \
# 87              Hugh Lawrence "Laurie"•Doherty        Laurie•Doherty
# 105                     Harold Segerson•Mahony         Harold•Mahony
# 165                      Patricia Akosua•Offel        Patricia•Offel
# 242    Lucia Francisca "Susy"•Susanti Haditono          Susy•Susanti
# 243                                 Lili•Tampi            Lili•Tampi
# ...                                        ...                   ...
# 21999                   Cecil Ashworth•Kershaw         Cecil•Kershaw
# 22007    Alfred Ridley•Martin (-Ridley-Martin)  Alfred•Ridley-Martin
# 22046              Thomas Harrison•Wand-Tetley    Thomas•Wand-Tetley
# 22050        Roland Moffatt Perowne•Willoughby     Roland•Willoughby
# 22090              Bernhard Artur Erwin•Casmir          Erwin•Casmir
#
#                                                     Born  \
# 87            8 October 1875 in Wimbledon, England (GBR)
# 105        13 February 1867 in Edinburgh, Scotland (GBR)
# 165                                     19 December 1971
# 242    11 February 1971 in Tasikmalaya, Jawa Barat (INA)
# 243         19 May 1970 in Tasikmalaya, Jawa Barat (INA)
# ...                                                  ...
# 21999      3 February 1895 in Dhaka (Dacca), Dhaka (BAN)
# 22007              9 May 1881 in Lewisham, England (GBR)
# 22046       26 September 1890 in Paignton, England (GBR)
# 22050      6 September 1870 in Marylebone, England (GBR)
# 22090           2 December 1895 in Spandau, Berlin (GER)
#
#                                                     Died            NOC  \
# 87          21 August 1919 in Broadstairs, England (GBR)  Great Britain
# 105    27 June 1905 in between Glencar and Killorgin,...  Great Britain
# 165                                                  NaN          Ghana
# 242                                                  NaN      Indonesia
# 243                                                  NaN      Indonesia
# ...                                                  ...            ...
# 21999         1 November 1972 in Worthing, England (GBR)  Great Britain
# 22007                6 May 1970 in Purley, England (GBR)  Great Britain
# 22046        4 February 1956 in Saint Mary, Jersey (JER)  Great Britain
# 22050         15 February 1954 in Chelsea, England (GBR)  Great Britain
# 22090   19 April 1982 in Frankfurt am Main, Hessen (GER)        Germany
#
#        athlete_id Measurements  \
# 87           88.0       178 cm
# 105         106.0       191 cm
# 165         166.0       120 kg
# 242         243.0       161 cm
# 243         244.0       161 cm
# ...           ...          ...
# 21999     22158.0       173 cm
# 22007     22166.0       188 cm
# 22046     22205.0       175 cm
# 22050     22210.0       178 cm
# 22090     22251.0       180 cm
#
#                                             Affiliations Nick/petnames  \
# 87     All England Lawn Tennis and Croquet Club, Wimb...     Little Do
# 105           Fitzwilliam Lawn Tennis Club, Dublin (IRL)           NaN
# 165                                                  NaN           NaN
# 242                             Jaya Raya, Jakarta (INA)           NaN
# 243                                                  NaN           NaN
# ...                                                  ...           ...
# 21999             Royal Navy School of Physical Training             K
# 22007                                                NaN           NaN
# 22046                             The Wiltshire Regiment           NaN
# 22050                  London Fencing Club, London (GBR)           NaN
# 22090              FC Hermannia, Frankfurt am Main (GER)           NaN
#
#       Title(s)          Other names   Nationality Original name Name order  \
# 87         NaN                  NaN           NaN           NaN        NaN
# 105        NaN                  NaN       Ireland           NaN        NaN
# 165        NaN                  NaN           NaN           NaN        NaN
# 242        NaN  Wang Lianxiang, 王蓮香           NaN           NaN        NaN
# 243        NaN                  NaN           NaN           NaN        NaN
# ...        ...                  ...           ...           ...        ...
# 21999      NaN                  NaN           NaN           NaN        NaN
# 22007      NaN                  NaN           NaN           NaN        NaN
# 22046      NaN                  NaN           NaN           NaN        NaN
# 22050      NaN                  NaN           NaN           NaN        NaN
# 22090      NaN                  NaN  West Germany           NaN        NaN
#
#                        name height_cm weight_kg
# 87           Laurie Doherty    178 cm      None
# 105           Harold Mahony    191 cm      None
# 165          Patricia Offel    120 kg      None
# 242            Susy Susanti    161 cm      None
# 243              Lili Tampi    161 cm      None
# ...                     ...       ...       ...
# 21999         Cecil Kershaw    173 cm      None
# 22007  Alfred Ridley-Martin    188 cm      None
# 22046    Thomas Wand-Tetley    175 cm      None
# 22050     Roland Willoughby    178 cm      None
# 22090          Erwin Casmir    180 cm      None
#
# [794 rows x 19 columns]

# %%
# small_data['height_cm'] = pd.to_numeric(small_data['height_cm'].str.strip(' cm'), errors='coerce')
# small_data.head()
# Out:
#       Measurements  height_cm weight_kg
# 0           183 cm      183.0      None
# 1  180 cm / 150 kg      180.0    150 kg
# 2   190 cm / 80 kg      190.0     80 kg
# 3           100 kg        NaN      None

# %%
# Get rid of " cm" and the " kg" from our new columns
df['height_cm'] = pd.to_numeric(df['height_cm'].str.strip(' cm'), errors='coerce')
df['weight_kg'] = pd.to_numeric(df['weight_kg'].str.strip(' kg'), errors='coerce')

# %%
# Sorting Values
df.sort_values('height_cm', ascending = False)
# Out:
#                            Roles   Sex                            Full name  \
# 5781   Competed in Olympic Games  Male        Thomas Loren "Tommy"•Burleson
# 6978   Competed in Olympic Games  Male                Arvydas Romas•Sabonis
# 5673   Competed in Olympic Games  Male                       Gunther•Behnke
# 7188   Competed in Olympic Games  Male         Vladimir Petrovich•Tkachenko
# 6504   Competed in Olympic Games  Male           Lucien James "Luc"•Longley
# ...                          ...   ...                                  ...
# 22298  Competed in Olympic Games  Male                        Lajos•Horváth
# 22301  Competed in Olympic Games  Male                  Gyula Sámuel•Iványi
# 22302  Competed in Olympic Games  Male                  Endre•Kabos (Katz-)
# 22304  Competed in Olympic Games  Male  Gusztáv (Gyula)•Kálniczky (Csabuda)
# 22313  Competed in Olympic Games  Male                        Attila•Kovács
#
#                 Used name                                               Born  \
# 5781       Tommy•Burleson  24 February 1952 in Crossnore, North Carolina ...
# 6978      Arvydas•Sabonis           19 December 1964 in Kaunas, Kaunas (LTU)
# 5673       Gunther•Behnke  19 January 1963 in Leverkusen, Nordrhein-Westf...
# 7188   Vladimir•Tkachenko  20 September 1957 in Golovinka, Krasnodar Kray...
# 6504          Luc•Longley       19 January 1969 in Melbourne, Victoria (AUS)
# ...                   ...                                                ...
# 22298       Lajos•Horváth          18 March 1872 in Vințu de Jos, Alba (ROU)
# 22301        Gyula•Iványi          10 March 1864 in Budapest, Budapest (HUN)
# 22302         Endre•Kabos             5 November 1906 in Oradea, Bihor (ROU)
# 22304   Gusztáv•Kálniczky            17 May 1896 in Budapest, Budapest (HUN)
# 22313       Attila•Kovács       30 December 1939 in Budapest, Budapest (HUN)
#
#                                                Died                     NOC  \
# 5781                                            NaN           United States
# 6978                                            NaN  Lithuania Soviet Union
# 5673                                            NaN                 Germany
# 7188                                            NaN            Soviet Union
# 6504                                            NaN               Australia
# ...                                             ...                     ...
# 22298                                           NaN                 Hungary
# 22301   6 December 1920 in Budapest, Budapest (HUN)                 Hungary
# 22302   4 November 1944 in Budapest, Budapest (HUN)                 Hungary
# 22304                                          1964                 Hungary
# 22313  10 November 2010 in Budapest, Budapest (HUN)                    Hung
#
#        athlete_id     Measurements  \
# 5781       5804.0  223 cm / 102 kg
# 6978       7013.0  223 cm / 122 kg
# 5673       5696.0  221 cm / 114 kg
# 7188       7226.0  220 cm / 110 kg
# 6504       6537.0  220 cm / 135 kg
# ...           ...              ...
# 22298     22466.0              NaN
# 22301     22469.0              NaN
# 22302     22470.0              NaN
# 22304     22472.0              NaN
# 22313         NaN              NaN
#
#                                             Affiliations Nick/petnames  \
# 5781                    NC State Wolfpack, Raleigh (USA)           NaN
# 6978   Žalgiris Kaunas, Kaunas (LTU) / Real Madrid, M...         Sabas
# 5673                        TuS Bramsche, Bramsche (GER)           NaN
# 7188                           BC Budivelnyk, Kyiv (UKR)         Lurch
# 6504                         Phoenix Suns, Phoenix (USA)           NaN
# ...                                                  ...           ...
# 22298                                                NaN           NaN
# 22301                                MAC, Budapest (HUN)           NaN
# 22302                 Szolnoki TIVC/Újpesti Torna Egylet           NaN
# 22304            Honvéd Tiszti Vívó Klub, Budapest (HUN)           NaN
# 22313                                                NaN           NaN
#
#       Title(s)                                   Other names Nationality  \
# 5781       NaN                                           NaN         NaN
# 6978       NaN  Arvidas Romas Sabonis, Арвидас Ромас Сабонис   Lithuania
# 5673       NaN                                           NaN         NaN
# 7188       NaN                                           NaN         NaN
# 6504       NaN                                           NaN         NaN
# ...        ...                                           ...         ...
# 22298      NaN                                           NaN         NaN
# 22301      NaN                              Gyula von Iványi         NaN
# 22302      NaN                                           NaN         NaN
# 22304      NaN                             Gusztáv Kalnitzky         NaN
# 22313      NaN                                           NaN         NaN
#
#                     Original name Name order                name  height_cm  \
# 5781                          NaN        NaN      Tommy Burleson      223.0
# 6978                          NaN        NaN     Arvydas Sabonis      223.0
# 5673                          NaN        NaN      Gunther Behnke      221.0
# 7188   Владимир Петрович•Ткаченко        NaN  Vladimir Tkachenko      220.0
# 6504                          NaN        NaN         Luc Longley      220.0
# ...                           ...        ...                 ...        ...
# 22298                         NaN        NaN       Lajos Horváth        NaN
# 22301                         NaN        NaN        Gyula Iványi        NaN
# 22302                         NaN        NaN         Endre Kabos        NaN
# 22304                         NaN        NaN   Gusztáv Kálniczky        NaN
# 22313                         NaN        NaN       Attila Kovács        NaN
#
#        weight_kg
# 5781       102.0
# 6978       122.0
# 5673       114.0
# 7188       110.0
# 6504       135.0
# ...          ...
# 22298        NaN
# 22301        NaN
# 22302        NaN
# 22304        NaN
# 22313        NaN
#
# [22314 rows x 19 columns]

# %%
# Parse Out Dates from 'Born' and 'Died' Columns
date_pattern = r'(\d \w+ \d{4}|\d{4})'
df['born_date'] = df['Born'].str.extract(date_pattern)
df['born_year'] = df['Born'].str.extract(r'(\d{4})')

df['born_date'] = pd.to_datetime(df['born_date'], errors='coerce')
df['born_year'] = pd.to_numeric(df['born_year'], errors = 'coerce')

df['died_date'] = df['Died'].str.extract(date_pattern)
df['died_date'] = pd.to_datetime(df['died_date'], format="mixed", errors='coerce')

# %%
df.head()
# Out:
#                                        Roles   Sex  \
# 0                  Competed in Olympic Games  Male
# 1                  Competed in Olympic Games  Male
# 2  Competed in Olympic Games • Administrator  Male
# 3                  Competed in Olympic Games  Male
# 4                  Competed in Olympic Games  Male
#
#                                            Full name              Used name  \
# 0  François Joseph Marie Antoine "Jean-François"•...  Jean-François•Blanchy
# 1                            Arnaud Benjamin•Boetsch         Arnaud•Boetsch
# 2                        Jean Laurent Robert•Borotra           Jean•Borotra
# 3               Jacques Marie Stanislas Jean•Brugnon        Jacques•Brugnon
# 4                                 Henry Albert•Canet           Albert•Canet
#
#                                                 Born  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)
# 1             1 April 1969 in Meulan, Yvelines (FRA)
# 2  13 August 1898 in Biarritz, Pyrénées-Atlantiqu...
# 3            11 May 1895 in Paris VIIIe, Paris (FRA)
# 4         17 April 1878 in Wandsworth, England (GBR)
#
#                                                 Died     NOC  athlete_id  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...  France         1.0
# 1                                                NaN  France         2.0
# 2  17 July 1994 in Arbonne, Pyrénées-Atlantiques ...  France         3.0
# 3              20 March 1978 in Monaco, Monaco (MON)  France         4.0
# 4            25 July 1930 in Paris VIIe, Paris (FRA)  France         5.0
#
#      Measurements                         Affiliations  ... Other names  \
# 0             NaN                                  NaN  ...         NaN
# 1  183 cm / 76 kg   Racing Club de France, Paris (FRA)  ...         NaN
# 2  183 cm / 76 kg                     TCP, Paris (FRA)  ...         NaN
# 3  168 cm / 64 kg  Sporting club de Paris, Paris (FRA)  ...         NaN
# 4             NaN                     TCP, Paris (FRA)  ...         NaN
#
#   Nationality Original name Name order                   name height_cm  \
# 0         NaN           NaN        NaN  Jean-François Blanchy       NaN
# 1         NaN           NaN        NaN         Arnaud Boetsch     183.0
# 2         NaN           NaN        NaN           Jean Borotra     183.0
# 3         NaN           NaN        NaN        Jacques Brugnon     168.0
# 4         NaN           NaN        NaN           Albert Canet       NaN
#
#   weight_kg  born_date  born_year  died_date
# 0       NaN 1886-12-02     1886.0 1960-10-02
# 1      76.0 1969-04-01     1969.0        NaT
# 2      76.0 1898-08-03     1898.0 1994-07-07
# 3      64.0 1895-05-01     1895.0        NaT
# 4       NaN 1878-04-07     1878.0 1930-07-05
#
# [5 rows x 22 columns]

# %%
# Get city, region and country from Born column
location_pattern = r'in ([\w\s()-]+), ([\w\s-]+) \((\w+)\)'
df['Born'].str.extract(location_pattern)
# Out:
#                  0                     1    2
# 0         Bordeaux               Gironde  FRA
# 1           Meulan              Yvelines  FRA
# 2         Biarritz  Pyrénées-Atlantiques  FRA
# 3      Paris VIIIe                 Paris  FRA
# 4       Wandsworth               England  GBR
# ...            ...                   ...  ...
# 22309     Budapest              Budapest  HUN
# 22310     Budapest              Budapest  HUN
# 22311  Szombathely                   Vas  HUN
# 22312     Budapest              Budapest  HUN
# 22313     Budapest              Budapest  HUN
#
# [22314 rows x 3 columns]

# %%
df[['born_city', 'born_region', 'born_country']] = df['Born'].str.extract(location_pattern, expand=True)

# %%
df.head()
# Out:
#                                        Roles   Sex  \
# 0                  Competed in Olympic Games  Male
# 1                  Competed in Olympic Games  Male
# 2  Competed in Olympic Games • Administrator  Male
# 3                  Competed in Olympic Games  Male
# 4                  Competed in Olympic Games  Male
#
#                                            Full name              Used name  \
# 0  François Joseph Marie Antoine "Jean-François"•...  Jean-François•Blanchy
# 1                            Arnaud Benjamin•Boetsch         Arnaud•Boetsch
# 2                        Jean Laurent Robert•Borotra           Jean•Borotra
# 3               Jacques Marie Stanislas Jean•Brugnon        Jacques•Brugnon
# 4                                 Henry Albert•Canet           Albert•Canet
#
#                                                 Born  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)
# 1             1 April 1969 in Meulan, Yvelines (FRA)
# 2  13 August 1898 in Biarritz, Pyrénées-Atlantiqu...
# 3            11 May 1895 in Paris VIIIe, Paris (FRA)
# 4         17 April 1878 in Wandsworth, England (GBR)
#
#                                                 Died     NOC  athlete_id  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...  France         1.0
# 1                                                NaN  France         2.0
# 2  17 July 1994 in Arbonne, Pyrénées-Atlantiques ...  France         3.0
# 3              20 March 1978 in Monaco, Monaco (MON)  France         4.0
# 4            25 July 1930 in Paris VIIe, Paris (FRA)  France         5.0
#
#      Measurements                         Affiliations  ... Name order  \
# 0             NaN                                  NaN  ...        NaN
# 1  183 cm / 76 kg   Racing Club de France, Paris (FRA)  ...        NaN
# 2  183 cm / 76 kg                     TCP, Paris (FRA)  ...        NaN
# 3  168 cm / 64 kg  Sporting club de Paris, Paris (FRA)  ...        NaN
# 4             NaN                     TCP, Paris (FRA)  ...        NaN
#
#                     name height_cm weight_kg  born_date born_year  died_date  \
# 0  Jean-François Blanchy       NaN       NaN 1886-12-02    1886.0 1960-10-02
# 1         Arnaud Boetsch     183.0      76.0 1969-04-01    1969.0        NaT
# 2           Jean Borotra     183.0      76.0 1898-08-03    1898.0 1994-07-07
# 3        Jacques Brugnon     168.0      64.0 1895-05-01    1895.0        NaT
# 4           Albert Canet       NaN       NaN 1878-04-07    1878.0 1930-07-05
#
#      born_city           born_region born_country
# 0     Bordeaux               Gironde          FRA
# 1       Meulan              Yvelines          FRA
# 2     Biarritz  Pyrénées-Atlantiques          FRA
# 3  Paris VIIIe                 Paris          FRA
# 4   Wandsworth               England          GBR
#
# [5 rows x 25 columns]

# %%
import pandas as pd

# %%
pd.set_option('display.max_colwidth', None)

df.value_counts('born_city', ascending = False).head(25)
# Out:
# born_city
# Budapest                          233
# København (Copenhagen)            165
# Buenos Aires                      154
# Praha (Prague)                    128
# Wien (Vienna)                     116
# Madrid                             99
# Ciudad de México (Mexico City)     96
# Montréal                           95
# Amsterdam                          88
# Toronto                            87
# Moskva (Moscow)                    85
# Stockholm                          84
# Helsinki                           82
# Melbourne                          82
# London                             78
# Barcelona                          77
# New York                           72
# Montevideo                         72
# Berlin                             72
# São Paulo                          69
# Sydney                             67
# Oslo                               66
# Bruxelles (Brussels)               64
# Roma                               63
# Dublin                             58
# Name: count, dtype: int64

# %%
# Removing any Unneccasery columns
df.columns
# Out:
# Index(['Roles', 'Sex', 'Full name', 'Used name', 'Born', 'Died', 'NOC',
#        'athlete_id', 'Measurements', 'Affiliations', 'Nick/petnames',
#        'Title(s)', 'Other names', 'Nationality', 'Original name', 'Name order',
#        'name', 'height_cm', 'weight_kg', 'born_date', 'born_year', 'died_date',
#        'born_city', 'born_region', 'born_country'],
#       dtype='object')

# %%
columns_to_keep = ['athlete_id', 'name', 'born_date', 'born_city', 'born_region',
                   'born_country', 'NOC', 'height_cm', 'weight_kg', 'died_date']

df_clean = df[columns_to_keep]

# %%
df_clean.head()
# Out:
#    athlete_id                   name  born_date    born_city  \
# 0         1.0  Jean-François Blanchy 1886-12-02     Bordeaux
# 1         2.0         Arnaud Boetsch 1969-04-01       Meulan
# 2         3.0           Jean Borotra 1898-08-03     Biarritz
# 3         4.0        Jacques Brugnon 1895-05-01  Paris VIIIe
# 4         5.0           Albert Canet 1878-04-07   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  died_date
# 0               Gironde          FRA  France        NaN        NaN 1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0        NaT
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0 1994-07-07
# 3                 Paris          FRA  France      168.0       64.0        NaT
# 4               England          GBR  France        NaN        NaN 1930-07-05
